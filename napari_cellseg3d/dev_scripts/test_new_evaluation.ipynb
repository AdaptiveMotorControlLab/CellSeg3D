# %%
import evaluate_labels as evl
from tifffile import imread
import time
import numpy as np

# %%
from importlib import reload
reload(evl)
# Out:
# <module 'evaluate_labels' from 'C:\\Users\\Cyril\\Desktop\\Code\\CellSeg3D\\napari_cellseg3d\\dev_scripts\\evaluate_labels.py'>

# %%
from pathlib import Path
path_true_labels=Path.home() / "Desktop/Code/CELLSEG_BENCHMARK/RESULTS/full data/LABELS/relabel_gt.tif"

# %%
path_model_label=Path.home() / "Desktop/Code/CELLSEG_BENCHMARK/RESULTS/full data/instance/isotropic_visual_cp_masks(1).tif"
labels = imread(path_model_label)
# labels.shape
res = evl.evaluate_model_performance(imread(path_true_labels), labels,visualize=False, return_graphical_summary=True,plot_according_to_gt_label=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 4
#       2 labels = imread(path_model_label)
#       3 # labels.shape
# ----> 4 res = evl.evaluate_model_performance(imread(path_true_labels), labels,visualize=False, return_graphical_summary=True,plot_according_to_gt_label=False)
#
# File ~\Desktop\Code\CellSeg3D\napari_cellseg3d\dev_scripts\evaluate_labels.py:58, in evaluate_model_performance(labels, model_labels, threshold_correct, print_details, visualize, return_graphical_summary, plot_according_to_gt_label)
#      20 """Evaluate the model performance.
#      21 Parameters
#      22 ----------
#    (...)
#      55 graph_true_positive_ratio_model: ndarray
#      56 """
#      57 log.debug("Mapping labels...")
# ---> 58 tmp = map_labels(
#      59     labels,
#      60     model_labels,
#      61     threshold_correct,
# ...

# %%
path_model_label=Path.home() / "Desktop/Code/CELLSEG_BENCHMARK/RESULTS/full data/instance/instance_pred_WNet.tif"
res = evl.evaluate_model_performance(imread(path_true_labels), imread(path_model_label),visualize=False, return_graphical_summary=True,plot_according_to_gt_label=False)

# %%
path_model_label=Path.home() / "Desktop/Code/CELLSEG_BENCHMARK/RESULTS/full data/instance/stardist_labels.tif"
res = evl.evaluate_model_performance(imread(path_true_labels), imread(path_model_label),visualize=False, return_graphical_summary=True,plot_according_to_gt_label=False)

# %%
path_model_label=Path.home() / "Desktop/Code/CELLSEG_BENCHMARK/RESULTS/full data/instance/instance_threshold_pred_Swin_Generalized_latest(1).tif"
res = evl.evaluate_model_performance(imread(path_true_labels), imread(path_model_label),visualize=False, return_graphical_summary=True,plot_according_to_gt_label=False)

# %%
path_model_label=Path.home() / "Desktop/Code/CELLSEG_BENCHMARK/RESULTS/full data/instance/instance_threshold_pred_TRAILMAP_DiceCE_best_metric(1).tif"
res = evl.evaluate_model_performance(imread(path_true_labels), imread(path_model_label),visualize=False, return_graphical_summary=True,plot_according_to_gt_label=False)

# %%
path_model_label=Path.home() / "Desktop/Code/CELLSEG_BENCHMARK/RESULTS/full data/instance/instance_threshold_pred_VNet_Generalized_latest(1).tif"
res = evl.evaluate_model_performance(imread(path_true_labels), imread(path_model_label),visualize=False, return_graphical_summary=True,plot_according_to_gt_label=False)

# %%
path_model_label=Path.home() / "Desktop/Code/CELLSEG_BENCHMARK/RESULTS/full data/instance/instance_threshold_pred_SegResNet_Generalized_latest.tif"
res = evl.evaluate_model_performance(imread(path_true_labels), imread(path_model_label),visualize=False, return_graphical_summary=True,plot_according_to_gt_label=False)

# %%
from torchview import draw_graph
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'
from napari_cellseg3d.code_models.models.wnet.model import WNet

# %%
model = WNet()
batch_size = 1
# Out:
# (dot.exe:15460): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.

# %%
model_graph = draw_graph(model, input_size=(batch_size, 1, 64,64,64), device='cpu', expand_nested=True, depth=5)
model_graph.visual_graph
